# %% [raw]
# Question 1:
#
# Try to create the backpropagation and feedforward in python by creating function.

# %%
import numpy as np

# Considering sample data as follows
# X = (hours studying, hours sleeping), y = score on test
xAll = np.array(([2, 9], [1, 5], [3, 6], [5, 10]), dtype=float)  # input data
y = np.array(([92], [86], [89]), dtype=float)  # output

# scale units
xAll = xAll / np.amax(xAll, axis=0)  # scaling input data
y = y / 100  # scaling output data (max test score is 100)

# split data
X = np.split(xAll, [3])[0]  # training data
xPredicted = np.split(xAll, [3])[1]  # testing data

y = np.array(([92], [86], [89]), dtype=float)
y = y / 100  # max test score is 100


class Neural_Network(object):
    def __init__(self):
        #parameters
        self.inputSize = 2
        self.outputSize = 1
        self.hiddenSize = 3

        #weights
        self.W1 = np.random.randn(
            self.inputSize,
            self.hiddenSize)  # (3x2) weight matrix from input to hidden layer
        self.W2 = np.random.randn(
            self.hiddenSize,
            self.outputSize)  # (3x1) weight matrix from hidden to output layer

    def forward(self, X):
        #forward propagation through our network
        self.z = np.dot(
            X,
            self.W1)  # dot product of X (input) and first set of 3x2 weights
        self.z2 = self.sigmoid(self.z)  # activation function
        self.z3 = np.dot(
            self.z2, self.W2
        )  # dot product of hidden layer (z2) and second set of 3x1 weights
        o = self.sigmoid(self.z3)  # final activation function
        return o

    def sigmoid(self, s):
        # activation function
        return 1 / (1 + np.exp(-s))

    def sigmoidPrime(self, s):
        #derivative of sigmoid
        return s * (1 - s)

    def backward(self, X, y, o):
        # backward propagate through the network
        self.o_error = y - o  # error in output
        self.o_delta = self.o_error * self.sigmoidPrime(
            o)  # applying derivative of sigmoid to error

        self.z2_error = self.o_delta.dot(
            self.W2.T
        )  # z2 error: how much our hidden layer weights contributed to output error
        self.z2_delta = self.z2_error * self.sigmoidPrime(
            self.z2)  # applying derivative of sigmoid to z2 error

        self.W1 += X.T.dot(
            self.z2_delta)  # adjusting first set (input --> hidden) weights
        self.W2 += self.z2.T.dot(
            self.o_delta)  # adjusting second set (hidden --> output) weights

    def train(self, X, y):
        o = self.forward(X)
        self.backward(X, y, o)

    def saveWeights(self):
        np.savetxt("w1.txt", self.W1, fmt="%s")
        np.savetxt("w2.txt", self.W2, fmt="%s")

    def predict(self):
        print("Predicted data based on trained weights: ")
        print("Input (scaled): \n" + str(xPredicted))
        print("Output: \n" + str(self.forward(xPredicted)))


NN = Neural_Network()
for i in range(1000):  # trains the NN 1,000 times
    print("# " + str(i) + "\n")
    print("Input (scaled): \n" + str(X))
    print("Actual Output: \n" + str(y))
    print("Predicted Output: \n" + str(NN.forward(X)))
    print("Loss: \n" +
          str(np.mean(np.square(y - NN.forward(X)))))  # mean sum squared loss
    print("\n")
    NN.train(X, y)

NN.saveWeights()
NN.predict()
# Out:
# # 0
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.5639407 ]
#  [0.54078841]
#  [0.55660523]]
# Loss:
# 0.11327544509603309
#
#
# # 1
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.63401197]
#  [0.60354072]
#  [0.62589303]]
# Loss:
# 0.07243766863130381
#
#
# # 2
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.68460215]
#  [0.64963995]
#  [0.6761116 ]]
# Loss:
# 0.048470581460311135
#
#
# # 3
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.72123659]
#  [0.6836167 ]
#  [0.71260135]]
# Loss:
# 0.034029413692197565
#
#
# # 4
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.74846298]
#  [0.70928298]
#  [0.73980075]]
# Loss:
# 0.024900128078703242
#
#
# # 5
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.76931266]
#  [0.72922618]
#  [0.7606834 ]]
# Loss:
# 0.01884375076792823
#
#
# # 6
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.78572581]
#  [0.74512915]
#  [0.77715938]]
# Loss:
# 0.014652625447374385
#
#
# # 7
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.7989576 ]
#  [0.7580964 ]
#  [0.79046793]]
# Loss:
# 0.011647413171106928
#
#
# # 8
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8098415 ]
#  [0.76887094]
#  [0.80143395]]
# Loss:
# 0.009427782407340398
#
#
# # 9
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.81894738]
#  [0.77796682]
#  [0.81062267]]
# Loss:
# 0.007747278327171865
#
#
# # 10
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.82667605]
#  [0.7857495 ]
#  [0.81843236]]
# Loss:
# 0.006448141126959437
#
#
# # 11
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.83331673]
#  [0.79248533]
#  [0.82515094]]
# Loss:
# 0.005425873362591426
#
#
# # 12
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.83908304]
#  [0.79837281]
#  [0.83099137]]
# Loss:
# 0.004609161203676686
#
#
# # 13
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.84413601]
#  [0.80356283]
#  [0.83611443]]
# Loss:
# 0.003948051330721805
#
#
# # 14
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.84859928]
#  [0.80817216]
#  [0.84064372]]
# Loss:
# 0.00340674354667451
#
#
# # 15
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.85256931]
#  [0.81229259]
#  [0.84467582]]
# Loss:
# 0.002959058526215258
#
#
# # 16
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.85612251]
#  [0.81599729]
#  [0.84828729]]
# Loss:
# 0.002585507476044021
#
#
# # 17
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.85932015]
#  [0.81934532]
#  [0.8515396 ]]
# Loss:
# 0.0022713497688608875
#
#
# # 18
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86221197]
#  [0.82238492]
#  [0.85448271]]
# Loss:
# 0.0020052763519454986
#
#
# # 19
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86483876]
#  [0.82515587]
#  [0.85715762]]
# Loss:
# 0.001778499169740734
#
#
# # 20
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86723431]
#  [0.82769132]
#  [0.85959835]]
# Loss:
# 0.0015841098197608976
#
#
# # 21
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86942686]
#  [0.83001907]
#  [0.8618333 ]]
# Loss:
# 0.0014166203097254685
#
#
# # 22
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87144019]
#  [0.83216269]
#  [0.86388647]]
# Loss:
# 0.0012716292236111051
#
#
# # 23
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87329446]
#  [0.83414225]
#  [0.86577819]]
# Loss:
# 0.0011455756890392456
#
#
# # 24
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87500691]
#  [0.83597496]
#  [0.86752586]]
# Loss:
# 0.0010355557518993337
#
#
# # 25
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87659237]
#  [0.83767569]
#  [0.86914446]]
# Loss:
# 0.0009391837291205972
#
#
# # 26
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87806363]
#  [0.83925734]
#  [0.87064691]]
# Loss:
# 0.0008544863960051356
#
#
# # 27
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87943183]
#  [0.84073118]
#  [0.8720445 ]]
# Loss:
# 0.0007798214287560091
#
#
# # 28
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88070669]
#  [0.84210706]
#  [0.87334706]]
# Loss:
# 0.0007138139623705787
#
#
# # 29
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88189675]
#  [0.8433937 ]
#  [0.87456324]]
# Loss:
# 0.0006553068170492504
#
#
# # 30
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88300953]
#  [0.84459878]
#  [0.87570066]]
# Loss:
# 0.0006033211363621216
#
#
# # 31
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8840517 ]
#  [0.84572912]
#  [0.87676607]]
# Loss:
# 0.0005570250270937116
#
#
# # 32
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88502917]
#  [0.84679081]
#  [0.87776548]]
# Loss:
# 0.0005157083998330597
#
#
# # 33
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88594721]
#  [0.8477893 ]
#  [0.87870424]]
# Loss:
# 0.00047876265225437826
#
#
# # 34
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88681054]
#  [0.84872946]
#  [0.87958715]]
# Loss:
# 0.0004456641622116953
#
#
# # 35
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88762341]
#  [0.8496157 ]
#  [0.88041851]]
# Loss:
# 0.0004159607987487414
#
#
# # 36
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88838961]
#  [0.85045199]
#  [0.88120219]]
# Loss:
# 0.00038926083926795
#
#
# # 37
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88911261]
#  [0.8512419 ]
#  [0.8819417 ]]
# Loss:
# 0.00036522381687862276
#
#
# # 38
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88979551]
#  [0.85198871]
#  [0.88264021]]
# Loss:
# 0.00034355292507773014
#
#
# # 39
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89044113]
#  [0.85269538]
#  [0.8833006 ]]
# Loss:
# 0.0003239886858326652
#
#
# # 40
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89105207]
#  [0.85336461]
#  [0.88392548]]
# Loss:
# 0.0003063036479413176
#
#
# # 41
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89163065]
#  [0.85399887]
#  [0.88451726]]
# Loss:
# 0.00029029792970698736
#
#
# # 42
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89217904]
#  [0.85460043]
#  [0.88507811]]
# Loss:
# 0.0002757954567751951
#
#
# # 43
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89269918]
#  [0.85517137]
#  [0.88561004]]
# Loss:
# 0.00026264077488033353
#
#
# # 44
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89319288]
#  [0.85571359]
#  [0.88611488]]
# Loss:
# 0.0002506963400708572
#
#
# # 45
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89366181]
#  [0.85622885]
#  [0.88659433]]
# Loss:
# 0.0002398402070985656
#
#
# # 46
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89410747]
#  [0.85671879]
#  [0.88704995]]
# Loss:
# 0.00022996405111502948
#
#
# # 47
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89453129]
#  [0.8571849 ]
#  [0.88748316]]
# Loss:
# 0.0002209714694118098
#
#
# # 48
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89493456]
#  [0.85762856]
#  [0.8878953 ]]
# Loss:
# 0.0002127765192825157
#
#
# # 49
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89531849]
#  [0.85805108]
#  [0.8882876 ]]
# Loss:
# 0.0002053024556450435
#
#
# # 50
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8956842 ]
#  [0.85845364]
#  [0.8886612 ]]
# Loss:
# 0.0001984806382077541
#
#
# # 51
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89603271]
#  [0.85883735]
#  [0.88901716]]
# Loss:
# 0.00019224958297948727
#
#
# # 52
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89636499]
#  [0.85920327]
#  [0.88935647]]
# Loss:
# 0.00018655413703359285
#
#
# # 53
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89668195]
#  [0.85955234]
#  [0.88968003]]
# Loss:
# 0.0001813447588174537
#
#
# # 54
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89698441]
#  [0.85988547]
#  [0.88998872]]
# Loss:
# 0.00017657688909043464
#
#
# # 55
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89727315]
#  [0.8602035 ]
#  [0.89028331]]
# Loss:
# 0.00017221039988605104
#
#
# # 56
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89754891]
#  [0.86050723]
#  [0.89056457]]
# Loss:
# 0.00016820911081683314
#
#
# # 57
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89781237]
#  [0.86079738]
#  [0.89083318]]
# Loss:
# 0.0001645403636439071
#
#
# # 58
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89806415]
#  [0.86107466]
#  [0.89108981]]
# Loss:
# 0.00016117464737512593
#
#
# # 59
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89830487]
#  [0.86133971]
#  [0.89133506]]
# Loss:
# 0.0001580852672813443
#
#
# # 60
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89853508]
#  [0.86159315]
#  [0.89156951]]
# Loss:
# 0.00015524805216820208
#
#
# # 61
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89875531]
#  [0.86183554]
#  [0.8917937 ]]
# Loss:
# 0.0001526410950406166
#
#
# # 62
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89896606]
#  [0.86206743]
#  [0.89200813]]
# Loss:
# 0.00015024452297404214
#
#
# # 63
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89916778]
#  [0.86228932]
#  [0.8922133 ]]
# Loss:
# 0.00014804029258107653
#
#
# # 64
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89936093]
#  [0.8625017 ]
#  [0.89240963]]
# Loss:
# 0.00014601200795063177
#
#
# # 65
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89954591]
#  [0.86270502]
#  [0.89259757]]
# Loss:
# 0.00014414475835365813
#
#
# # 66
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89972311]
#  [0.8628997 ]
#  [0.89277751]]
# Loss:
# 0.00014242497336567416
#
#
# # 67
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89989291]
#  [0.86308615]
#  [0.89294982]]
# Loss:
# 0.0001408402933616382
#
#
# # 68
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90005564]
#  [0.86326475]
#  [0.89311487]]
# Loss:
# 0.00013937945360086826
#
#
# # 69
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90021165]
#  [0.86343586]
#  [0.89327299]]
# Loss:
# 0.00013803218034526388
#
#
# # 70
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90036123]
#  [0.86359983]
#  [0.89342451]]
# Loss:
# 0.00013678909764874283
#
#
# # 71
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90050469]
#  [0.86375697]
#  [0.89356971]]
# Loss:
# 0.00013564164362387193
#
#
# # 72
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9006423]
#  [0.8639076]
#  [0.8937089]]
# Loss:
# 0.00013458199513735237
#
#
# # 73
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90077432]
#  [0.86405201]
#  [0.89384234]]
# Loss:
# 0.00013360300001224966
#
#
# # 74
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90090102]
#  [0.86419046]
#  [0.89397029]]
# Loss:
# 0.00013269811592473733
#
#
# # 75
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90102262]
#  [0.86432323]
#  [0.89409299]]
# Loss:
# 0.00013186135527864303
#
#
# # 76
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90113934]
#  [0.86445057]
#  [0.89421068]]
# Loss:
# 0.00013108723542455336
#
#
# # 77
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90125142]
#  [0.86457271]
#  [0.89432357]]
# Loss:
# 0.0001303707336630075
#
#
# # 78
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90135904]
#  [0.86468987]
#  [0.89443188]]
# Loss:
# 0.0001297072465351966
#
#
# # 79
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90146241]
#  [0.86480227]
#  [0.8945358 ]]
# Loss:
# 0.00012909255296040162
#
#
# # 80
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9015617 ]
#  [0.86491012]
#  [0.89463552]]
# Loss:
# 0.00012852278082852003
#
#
# # 81
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90165709]
#  [0.86501361]
#  [0.89473123]]
# Loss:
# 0.0001279943766992163
#
#
# # 82
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90174875]
#  [0.86511292]
#  [0.89482309]]
# Loss:
# 0.00012750407829722286
#
#
# # 83
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90183684]
#  [0.86520823]
#  [0.89491127]]
# Loss:
# 0.00012704888952684999
#
#
# # 84
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9019215 ]
#  [0.86529971]
#  [0.89499592]]
# Loss:
# 0.00012662605775840618
#
#
# # 85
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90200289]
#  [0.86538752]
#  [0.8950772 ]]
# Loss:
# 0.00012623305316535123
#
#
# # 86
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90208114]
#  [0.86547181]
#  [0.89515524]]
# Loss:
# 0.0001258675499142807
#
#
# # 87
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90215638]
#  [0.86555272]
#  [0.89523018]]
# Loss:
# 0.00012552740903035747
#
#
# # 88
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90222874]
#  [0.86563041]
#  [0.89530215]]
# Loss:
# 0.00012521066277903752
#
#
# # 89
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90229833]
#  [0.86570499]
#  [0.89537126]]
# Loss:
# 0.0001249155004212859
#
#
# # 90
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90236527]
#  [0.86577661]
#  [0.89543765]]
# Loss:
# 0.0001246402552137625
#
#
# # 91
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90242968]
#  [0.86584537]
#  [0.89550141]]
# Loss:
# 0.00012438339253848714
#
#
# # 92
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90249164]
#  [0.86591139]
#  [0.89556267]]
# Loss:
# 0.00012414349905787595
#
#
# # 93
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90255127]
#  [0.86597479]
#  [0.89562151]]
# Loss:
# 0.00012391927280133944
#
#
# # 94
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90260865]
#  [0.86603568]
#  [0.89567804]]
# Loss:
# 0.00012370951409880617
#
#
# # 95
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90266389]
#  [0.86609415]
#  [0.89573235]]
# Loss:
# 0.00012351311728473258
#
#
# # 96
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90271705]
#  [0.8661503 ]
#  [0.89578454]]
# Loss:
# 0.00012332906310350805
#
#
# # 97
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90276824]
#  [0.86620422]
#  [0.89583467]]
# Loss:
# 0.00012315641175378683
#
#
# # 98
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90281753]
#  [0.866256  ]
#  [0.89588285]]
# Loss:
# 0.00012299429651516333
#
#
# # 99
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90286499]
#  [0.86630574]
#  [0.89592915]]
# Loss:
# 0.00012284191790596199
#
#
# # 100
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9029107 ]
#  [0.8663535 ]
#  [0.89597364]]
# Loss:
# 0.00012269853832567396
#
#
# # 101
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90295472]
#  [0.86639937]
#  [0.89601639]]
# Loss:
# 0.0001225634771398739
#
#
# # 102
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90299713]
#  [0.86644342]
#  [0.89605747]]
# Loss:
# 0.00012243610616939233
#
#
# # 103
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90303799]
#  [0.86648573]
#  [0.89609696]]
# Loss:
# 0.00012231584554891196
#
#
# # 104
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90307735]
#  [0.86652636]
#  [0.8961349 ]]
# Loss:
# 0.00012220215992341738
#
#
# # 105
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90311529]
#  [0.86656538]
#  [0.89617137]]
# Loss:
# 0.0001220945549537518
#
#
# # 106
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90315184]
#  [0.86660286]
#  [0.89620642]]
# Loss:
# 0.00012199257410503973
#
#
# # 107
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90318708]
#  [0.86663884]
#  [0.89624011]]
# Loss:
# 0.00012189579569420494
#
#
# # 108
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90322105]
#  [0.8666734 ]
#  [0.89627249]]
# Loss:
# 0.00012180383017480679
#
#
# # 109
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9032538 ]
#  [0.86670658]
#  [0.89630361]]
# Loss:
# 0.00012171631763939189
#
#
# # 110
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90328537]
#  [0.86673844]
#  [0.89633352]]
# Loss:
# 0.00012163292552127755
#
#
# # 111
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90331582]
#  [0.86676904]
#  [0.89636226]]
# Loss:
# 0.00012155334647926335
#
#
# # 112
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90334519]
#  [0.86679841]
#  [0.89638989]]
# Loss:
# 0.00012147729645018016
#
#
# # 113
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90337351]
#  [0.86682662]
#  [0.89641645]]
# Loss:
# 0.00012140451285553233
#
#
# # 114
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90340084]
#  [0.86685369]
#  [0.89644197]]
# Loss:
# 0.00012133475294959083
#
#
# # 115
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9034272 ]
#  [0.86687969]
#  [0.89646651]]
# Loss:
# 0.0001212677922974534
#
#
# # 116
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90345264]
#  [0.86690464]
#  [0.89649008]]
# Loss:
# 0.00012120342337250205
#
#
# # 117
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90347719]
#  [0.86692859]
#  [0.89651274]]
# Loss:
# 0.00012114145426363427
#
#
# # 118
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90350089]
#  [0.86695158]
#  [0.89653452]]
# Loss:
# 0.00012108170748336723
#
#
# # 119
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90352376]
#  [0.86697364]
#  [0.89655545]]
# Loss:
# 0.00012102401886879998
#
#
# # 120
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90354584]
#  [0.86699481]
#  [0.89657557]]
# Loss:
# 0.0001209682365679113
#
#
# # 121
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90356717]
#  [0.86701512]
#  [0.8965949 ]]
# Loss:
# 0.00012091422010446044
#
#
# # 122
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90358776]
#  [0.86703462]
#  [0.89661348]]
# Loss:
# 0.00012086183951519972
#
#
# # 123
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90360765]
#  [0.86705332]
#  [0.89663133]]
# Loss:
# 0.00012081097455366635
#
#
# # 124
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90362686]
#  [0.86707125]
#  [0.89664849]]
# Loss:
# 0.00012076151395530811
#
#
# # 125
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90364543]
#  [0.86708846]
#  [0.89666497]]
# Loss:
# 0.00012071335475910242
#
#
# # 126
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90366337]
#  [0.86710496]
#  [0.89668081]]
# Loss:
# 0.00012066640168120854
#
#
# # 127
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90368071]
#  [0.86712078]
#  [0.89669603]]
# Loss:
# 0.00012062056653658934
#
#
# # 128
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90369747]
#  [0.86713596]
#  [0.89671065]]
# Loss:
# 0.00012057576770486554
#
#
# # 129
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90371367]
#  [0.8671505 ]
#  [0.8967247 ]]
# Loss:
# 0.00012053192963691264
#
#
# # 130
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90372934]
#  [0.86716444]
#  [0.89673819]]
# Loss:
# 0.0001204889823990599
#
#
# # 131
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90374449]
#  [0.8671778 ]
#  [0.89675116]]
# Loss:
# 0.00012044686125195436
#
#
# # 132
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90375914]
#  [0.8671906 ]
#  [0.89676361]]
# Loss:
# 0.00012040550626142298
#
#
# # 133
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90377333]
#  [0.86720287]
#  [0.89677557]]
# Loss:
# 0.00012036486193883534
#
#
# # 134
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90378705]
#  [0.86721461]
#  [0.89678706]]
# Loss:
# 0.00012032487690871142
#
#
# # 135
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90380033]
#  [0.86722586]
#  [0.89679809]]
# Loss:
# 0.00012028550360144697
#
#
# # 136
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90381318]
#  [0.86723663]
#  [0.89680868]]
# Loss:
# 0.00012024669796928498
#
#
# # 137
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90382563]
#  [0.86724694]
#  [0.89681886]]
# Loss:
# 0.0001202084192236637
#
#
# # 138
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90383768]
#  [0.86725681]
#  [0.89682862]]
# Loss:
# 0.00012017062959238361
#
#
# # 139
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90384936]
#  [0.86726625]
#  [0.896838  ]]
# Loss:
# 0.00012013329409504305
#
#
# # 140
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90386067]
#  [0.86727529]
#  [0.896847  ]]
# Loss:
# 0.00012009638033533438
#
#
# # 141
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90387163]
#  [0.86728392]
#  [0.89685564]]
# Loss:
# 0.00012005985830896102
#
#
# # 142
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90388226]
#  [0.86729218]
#  [0.89686393]]
# Loss:
# 0.00012002370022592961
#
#
# # 143
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90389256]
#  [0.86730007]
#  [0.89687189]]
# Loss:
# 0.00011998788034618007
#
#
# # 144
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90390254]
#  [0.86730761]
#  [0.89687953]]
# Loss:
# 0.00011995237482750561
#
#
# # 145
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90391223]
#  [0.86731481]
#  [0.89688685]]
# Loss:
# 0.00011991716158484292
#
#
# # 146
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90392163]
#  [0.86732168]
#  [0.89689388]]
# Loss:
# 0.00011988222016008924
#
#
# # 147
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90393075]
#  [0.86732825]
#  [0.89690062]]
# Loss:
# 0.00011984753160161312
#
#
# # 148
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9039396 ]
#  [0.86733451]
#  [0.89690709]]
# Loss:
# 0.00011981307835276466
#
#
# # 149
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90394819]
#  [0.86734047]
#  [0.89691329]]
# Loss:
# 0.00011977884414869141
#
#
# # 150
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90395654]
#  [0.86734616]
#  [0.89691923]]
# Loss:
# 0.00011974481392084043
#
#
# # 151
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90396465]
#  [0.86735159]
#  [0.89692492]]
# Loss:
# 0.00011971097370855296
#
#
# # 152
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90397252]
#  [0.86735675]
#  [0.89693038]]
# Loss:
# 0.00011967731057723533
#
#
# # 153
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90398018]
#  [0.86736166]
#  [0.89693562]]
# Loss:
# 0.00011964381254262579
#
#
# # 154
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90398762]
#  [0.86736633]
#  [0.89694063]]
# Loss:
# 0.00011961046850065318
#
#
# # 155
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90399486]
#  [0.86737078]
#  [0.89694543]]
# Loss:
# 0.00011957726816252377
#
#
# # 156
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9040019 ]
#  [0.867375  ]
#  [0.89695003]]
# Loss:
# 0.00011954420199461234
#
#
# # 157
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90400875]
#  [0.867379  ]
#  [0.89695443]]
# Loss:
# 0.00011951126116281337
#
#
# # 158
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90401542]
#  [0.8673828 ]
#  [0.89695864]]
# Loss:
# 0.00011947843748098801
#
#
# # 159
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90402191]
#  [0.86738641]
#  [0.89696267]]
# Loss:
# 0.00011944572336326847
#
#
# # 160
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90402823]
#  [0.86738982]
#  [0.89696653]]
# Loss:
# 0.00011941311177985057
#
#
# # 161
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90403439]
#  [0.86739305]
#  [0.89697022]]
# Loss:
# 0.0001193805962160843
#
#
# # 162
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90404039]
#  [0.8673961 ]
#  [0.89697375]]
# Loss:
# 0.00011934817063456568
#
#
# # 163
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90404624]
#  [0.86739898]
#  [0.89697712]]
# Loss:
# 0.00011931582944004023
#
#
# # 164
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90405195]
#  [0.8674017 ]
#  [0.89698034]]
# Loss:
# 0.00011928356744689862
#
#
# # 165
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90405751]
#  [0.86740426]
#  [0.89698342]]
# Loss:
# 0.00011925137984906102
#
#
# # 166
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90406294]
#  [0.86740667]
#  [0.89698635]]
# Loss:
# 0.00011921926219209408
#
#
# # 167
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90406824]
#  [0.86740893]
#  [0.89698916]]
# Loss:
# 0.00011918721034737694
#
#
# # 168
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90407341]
#  [0.86741105]
#  [0.89699184]]
# Loss:
# 0.00011915522048816675
#
#
# # 169
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90407847]
#  [0.86741304]
#  [0.89699439]]
# Loss:
# 0.00011912328906744228
#
#
# # 170
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90408341]
#  [0.8674149 ]
#  [0.89699682]]
# Loss:
# 0.00011909141279736557
#
#
# # 171
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90408823]
#  [0.86741663]
#  [0.89699914]]
# Loss:
# 0.0001190595886302591
#
#
# # 172
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90409295]
#  [0.86741825]
#  [0.89700135]]
# Loss:
# 0.00011902781374099383
#
#
# # 173
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90409757]
#  [0.86741974]
#  [0.89700345]]
# Loss:
# 0.00011899608551064296
#
#
# # 174
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90410208]
#  [0.86742113]
#  [0.89700545]]
# Loss:
# 0.00011896440151137995
#
#
# # 175
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9041065 ]
#  [0.8674224 ]
#  [0.89700735]]
# Loss:
# 0.00011893275949245018
#
#
# # 176
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90411083]
#  [0.86742358]
#  [0.89700915]]
# Loss:
# 0.00011890115736719682
#
#
# # 177
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90411507]
#  [0.86742465]
#  [0.89701087]]
# Loss:
# 0.00011886959320102971
#
#
# # 178
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90411922]
#  [0.86742563]
#  [0.89701249]]
# Loss:
# 0.00011883806520027365
#
#
# # 179
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90412329]
#  [0.86742651]
#  [0.89701404]]
# Loss:
# 0.00011880657170185431
#
#
# # 180
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90412728]
#  [0.86742731]
#  [0.8970155 ]]
# Loss:
# 0.00011877511116371976
#
#
# # 181
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9041312 ]
#  [0.86742802]
#  [0.89701688]]
# Loss:
# 0.00011874368215597774
#
#
# # 182
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90413504]
#  [0.86742865]
#  [0.89701818]]
# Loss:
# 0.00011871228335268005
#
#
# # 183
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90413881]
#  [0.8674292 ]
#  [0.89701942]]
# Loss:
# 0.00011868091352421014
#
#
# # 184
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90414251]
#  [0.86742968]
#  [0.89702058]]
# Loss:
# 0.00011864957153023256
#
#
# # 185
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90414614]
#  [0.86743008]
#  [0.89702168]]
# Loss:
# 0.00011861825631314647
#
#
# # 186
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90414972]
#  [0.86743041]
#  [0.89702271]]
# Loss:
# 0.00011858696689203933
#
#
# # 187
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90415323]
#  [0.86743067]
#  [0.89702368]]
# Loss:
# 0.00011855570235706912
#
#
# # 188
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90415668]
#  [0.86743087]
#  [0.89702458]]
# Loss:
# 0.00011852446186426147
#
#
# # 189
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90416008]
#  [0.867431  ]
#  [0.89702543]]
# Loss:
# 0.00011849324463068457
#
#
# # 190
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90416342]
#  [0.86743108]
#  [0.89702623]]
# Loss:
# 0.00011846204993000028
#
#
# # 191
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90416671]
#  [0.86743109]
#  [0.89702697]]
# Loss:
# 0.00011843087708829476
#
#
# # 192
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90416995]
#  [0.86743105]
#  [0.89702766]]
# Loss:
# 0.00011839972548027101
#
#
# # 193
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90417314]
#  [0.86743096]
#  [0.8970283 ]]
# Loss:
# 0.00011836859452567232
#
#
# # 194
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90417628]
#  [0.86743081]
#  [0.89702889]]
# Loss:
# 0.00011833748368600492
#
#
# # 195
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90417938]
#  [0.86743061]
#  [0.89702944]]
# Loss:
# 0.00011830639246146158
#
#
# # 196
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90418243]
#  [0.86743037]
#  [0.89702994]]
# Loss:
# 0.00011827532038811213
#
#
# # 197
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90418544]
#  [0.86743008]
#  [0.8970304 ]]
# Loss:
# 0.00011824426703526752
#
#
# # 198
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90418841]
#  [0.86742974]
#  [0.89703082]]
# Loss:
# 0.00011821323200306045
#
#
# # 199
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90419135]
#  [0.86742936]
#  [0.8970312 ]]
# Loss:
# 0.00011818221492017489
#
#
# # 200
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90419424]
#  [0.86742894]
#  [0.89703154]]
# Loss:
# 0.00011815121544177401
#
#
# # 201
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9041971 ]
#  [0.86742848]
#  [0.89703184]]
# Loss:
# 0.0001181202332475577
#
#
# # 202
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90419993]
#  [0.86742799]
#  [0.89703211]]
# Loss:
# 0.0001180892680399684
#
#
# # 203
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90420272]
#  [0.86742745]
#  [0.89703234]]
# Loss:
# 0.00011805831954253034
#
#
# # 204
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90420548]
#  [0.86742688]
#  [0.89703255]]
# Loss:
# 0.00011802738749830962
#
#
# # 205
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90420821]
#  [0.86742628]
#  [0.89703272]]
# Loss:
# 0.0001179964716684804
#
#
# # 206
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90421091]
#  [0.86742564]
#  [0.89703286]]
# Loss:
# 0.00011796557183100697
#
#
# # 207
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90421358]
#  [0.86742497]
#  [0.89703297]]
# Loss:
# 0.00011793468777941602
#
#
# # 208
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90421622]
#  [0.86742428]
#  [0.89703305]]
# Loss:
# 0.0001179038193216578
#
#
# # 209
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90421883]
#  [0.86742355]
#  [0.89703311]]
# Loss:
# 0.00011787296627905061
#
#
# # 210
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90422142]
#  [0.86742279]
#  [0.89703314]]
# Loss:
# 0.00011784212848530851
#
#
# # 211
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90422399]
#  [0.86742201]
#  [0.89703314]]
# Loss:
# 0.00011781130578563091
#
#
# # 212
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90422653]
#  [0.8674212 ]
#  [0.89703312]]
# Loss:
# 0.00011778049803586542
#
#
# # 213
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90422904]
#  [0.86742037]
#  [0.89703308]]
# Loss:
# 0.00011774970510173404
#
#
# # 214
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90423154]
#  [0.86741951]
#  [0.89703301]]
# Loss:
# 0.00011771892685810622
#
#
# # 215
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90423401]
#  [0.86741863]
#  [0.89703293]]
# Loss:
# 0.00011768816318832836
#
#
# # 216
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90423647]
#  [0.86741773]
#  [0.89703282]]
# Loss:
# 0.00011765741398361417
#
#
# # 217
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9042389 ]
#  [0.8674168 ]
#  [0.89703269]]
# Loss:
# 0.00011762667914245872
#
#
# # 218
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424131]
#  [0.86741586]
#  [0.89703255]]
# Loss:
# 0.00011759595857011974
#
#
# # 219
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424371]
#  [0.86741489]
#  [0.89703238]]
# Loss:
# 0.00011756525217810854
#
#
# # 220
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424609]
#  [0.86741391]
#  [0.8970322 ]]
# Loss:
# 0.00011753455988375067
#
#
# # 221
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424845]
#  [0.86741291]
#  [0.897032  ]]
# Loss:
# 0.00011750388160974437
#
#
# # 222
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425079]
#  [0.86741189]
#  [0.89703178]]
# Loss:
# 0.0001174732172837796
#
#
# # 223
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425312]
#  [0.86741085]
#  [0.89703155]]
# Loss:
# 0.0001174425668381669
#
#
# # 224
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425543]
#  [0.8674098 ]
#  [0.8970313 ]]
# Loss:
# 0.00011741193020951069
#
#
# # 225
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425773]
#  [0.86740873]
#  [0.89703104]]
# Loss:
# 0.00011738130733838263
#
#
# # 226
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426001]
#  [0.86740765]
#  [0.89703076]]
# Loss:
# 0.00011735069816903714
#
#
# # 227
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426228]
#  [0.86740655]
#  [0.89703047]]
# Loss:
# 0.00011732010264914852
#
#
# # 228
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426454]
#  [0.86740544]
#  [0.89703017]]
# Loss:
# 0.00011728952072955195
#
#
# # 229
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426678]
#  [0.86740431]
#  [0.89702986]]
# Loss:
# 0.00011725895236402252
#
#
# # 230
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426901]
#  [0.86740318]
#  [0.89702953]]
# Loss:
# 0.00011722839750905159
#
#
# # 231
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90427123]
#  [0.86740203]
#  [0.89702919]]
# Loss:
# 0.00011719785612365214
#
#
# # 232
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90427344]
#  [0.86740086]
#  [0.89702884]]
# Loss:
# 0.00011716732816918281
#
#
# # 233
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90427564]
#  [0.86739969]
#  [0.89702848]]
# Loss:
# 0.00011713681360916551
#
#
# # 234
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90427783]
#  [0.86739851]
#  [0.89702811]]
# Loss:
# 0.00011710631240912738
#
#
# # 235
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90428   ]
#  [0.86739731]
#  [0.89702772]]
# Loss:
# 0.00011707582453646729
#
#
# # 236
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90428217]
#  [0.86739611]
#  [0.89702733]]
# Loss:
# 0.00011704534996030915
#
#
# # 237
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90428432]
#  [0.86739489]
#  [0.89702693]]
# Loss:
# 0.00011701488865137756
#
#
# # 238
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90428647]
#  [0.86739367]
#  [0.89702652]]
# Loss:
# 0.00011698444058188521
#
#
# # 239
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90428861]
#  [0.86739243]
#  [0.8970261 ]]
# Loss:
# 0.0001169540057254194
#
#
# # 240
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90429074]
#  [0.86739119]
#  [0.89702568]]
# Loss:
# 0.00011692358405684381
#
#
# # 241
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90429286]
#  [0.86738994]
#  [0.89702524]]
# Loss:
# 0.00011689317555220913
#
#
# # 242
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90429497]
#  [0.86738868]
#  [0.8970248 ]]
# Loss:
# 0.0001168627801886698
#
#
# # 243
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90429708]
#  [0.86738742]
#  [0.89702435]]
# Loss:
# 0.00011683239794438282
#
#
# # 244
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90429918]
#  [0.86738614]
#  [0.8970239 ]]
# Loss:
# 0.0001168020287984624
#
#
# # 245
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90430127]
#  [0.86738486]
#  [0.89702343]]
# Loss:
# 0.0001167716727308994
#
#
# # 246
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90430335]
#  [0.86738358]
#  [0.89702296]]
# Loss:
# 0.00011674132972248957
#
#
# # 247
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90430543]
#  [0.86738228]
#  [0.89702249]]
# Loss:
# 0.00011671099975478642
#
#
# # 248
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9043075 ]
#  [0.86738098]
#  [0.897022  ]]
# Loss:
# 0.00011668068281004052
#
#
# # 249
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90430956]
#  [0.86737968]
# ...
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90549095]
#  [0.86651086]
#  [0.89661828]]
# Loss:
# 9.890188049281715e-05
#
#
# # 918
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90549257]
#  [0.8665097 ]
#  [0.8966177 ]]
# Loss:
# 9.887853970008968e-05
#
#
# # 919
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9054942 ]
#  [0.86650854]
#  [0.89661712]]
# Loss:
# 9.885520725837065e-05
#
#
# # 920
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90549583]
#  [0.86650739]
#  [0.89661654]]
# Loss:
# 9.883188316263843e-05
#
#
# # 921
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90549745]
#  [0.86650623]
#  [0.89661596]]
# Loss:
# 9.880856740786817e-05
#
#
# # 922
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90549908]
#  [0.86650507]
#  [0.89661537]]
# Loss:
# 9.878525998904467e-05
#
#
# # 923
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90550071]
#  [0.86650391]
#  [0.89661479]]
# Loss:
# 9.876196090115172e-05
#
#
# # 924
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90550233]
#  [0.86650276]
#  [0.89661421]]
# Loss:
# 9.873867013918037e-05
#
#
# # 925
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90550396]
#  [0.8665016 ]
#  [0.89661363]]
# Loss:
# 9.871538769812568e-05
#
#
# # 926
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90550558]
#  [0.86650044]
#  [0.89661305]]
# Loss:
# 9.869211357299108e-05
#
#
# # 927
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9055072 ]
#  [0.86649929]
#  [0.89661246]]
# Loss:
# 9.866884775877258e-05
#
#
# # 928
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90550883]
#  [0.86649813]
#  [0.89661188]]
# Loss:
# 9.864559025048197e-05
#
#
# # 929
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90551045]
#  [0.86649698]
#  [0.8966113 ]]
# Loss:
# 9.862234104312646e-05
#
#
# # 930
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90551207]
#  [0.86649582]
#  [0.89661072]]
# Loss:
# 9.859910013172749e-05
#
#
# # 931
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9055137 ]
#  [0.86649467]
#  [0.89661014]]
# Loss:
# 9.857586751129874e-05
#
#
# # 932
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90551532]
#  [0.86649351]
#  [0.89660956]]
# Loss:
# 9.855264317686653e-05
#
#
# # 933
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90551694]
#  [0.86649236]
#  [0.89660898]]
# Loss:
# 9.852942712345948e-05
#
#
# # 934
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90551856]
#  [0.8664912 ]
#  [0.89660839]]
# Loss:
# 9.850621934610697e-05
#
#
# # 935
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90552018]
#  [0.86649005]
#  [0.89660781]]
# Loss:
# 9.848301983984607e-05
#
#
# # 936
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9055218 ]
#  [0.8664889 ]
#  [0.89660723]]
# Loss:
# 9.845982859971625e-05
#
#
# # 937
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90552342]
#  [0.86648775]
#  [0.89660665]]
# Loss:
# 9.843664562076425e-05
#
#
# # 938
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90552504]
#  [0.8664866 ]
#  [0.89660607]]
# Loss:
# 9.8413470898033e-05
#
#
# # 939
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90552666]
#  [0.86648544]
#  [0.89660549]]
# Loss:
# 9.83903044265826e-05
#
#
# # 940
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90552828]
#  [0.86648429]
#  [0.89660491]]
# Loss:
# 9.836714620146096e-05
#
#
# # 941
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9055299 ]
#  [0.86648314]
#  [0.89660433]]
# Loss:
# 9.834399621773117e-05
#
#
# # 942
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90553152]
#  [0.86648199]
#  [0.89660375]]
# Loss:
# 9.832085447046127e-05
#
#
# # 943
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90553314]
#  [0.86648084]
#  [0.89660317]]
# Loss:
# 9.829772095471689e-05
#
#
# # 944
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90553476]
#  [0.86647969]
#  [0.89660259]]
# Loss:
# 9.827459566557153e-05
#
#
# # 945
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90553638]
#  [0.86647854]
#  [0.89660201]]
# Loss:
# 9.825147859809942e-05
#
#
# # 946
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90553799]
#  [0.8664774 ]
#  [0.89660143]]
# Loss:
# 9.822836974738426e-05
#
#
# # 947
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90553961]
#  [0.86647625]
#  [0.89660084]]
# Loss:
# 9.820526910850966e-05
#
#
# # 948
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90554123]
#  [0.8664751 ]
#  [0.89660026]]
# Loss:
# 9.818217667656374e-05
#
#
# # 949
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90554284]
#  [0.86647395]
#  [0.89659968]]
# Loss:
# 9.815909244664167e-05
#
#
# # 950
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90554446]
#  [0.86647281]
#  [0.8965991 ]]
# Loss:
# 9.81360164138362e-05
#
#
# # 951
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90554607]
#  [0.86647166]
#  [0.89659852]]
# Loss:
# 9.81129485732502e-05
#
#
# # 952
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90554769]
#  [0.86647051]
#  [0.89659794]]
# Loss:
# 9.808988891999171e-05
#
#
# # 953
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9055493 ]
#  [0.86646937]
#  [0.89659736]]
# Loss:
# 9.806683744916388e-05
#
#
# # 954
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90555092]
#  [0.86646822]
#  [0.89659678]]
# Loss:
# 9.804379415588483e-05
#
#
# # 955
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90555253]
#  [0.86646708]
#  [0.8965962 ]]
# Loss:
# 9.80207590352692e-05
#
#
# # 956
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90555415]
#  [0.86646593]
#  [0.89659562]]
# Loss:
# 9.799773208243889e-05
#
#
# # 957
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90555576]
#  [0.86646479]
#  [0.89659505]]
# Loss:
# 9.797471329251921e-05
#
#
# # 958
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90555737]
#  [0.86646364]
#  [0.89659447]]
# Loss:
# 9.795170266063467e-05
#
#
# # 959
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90555899]
#  [0.8664625 ]
#  [0.89659389]]
# Loss:
# 9.792870018192293e-05
#
#
# # 960
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9055606 ]
#  [0.86646136]
#  [0.89659331]]
# Loss:
# 9.790570585152033e-05
#
#
# # 961
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90556221]
#  [0.86646021]
#  [0.89659273]]
# Loss:
# 9.788271966456977e-05
#
#
# # 962
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90556382]
#  [0.86645907]
#  [0.89659215]]
# Loss:
# 9.78597416162107e-05
#
#
# # 963
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90556543]
#  [0.86645793]
#  [0.89659157]]
# Loss:
# 9.783677170159564e-05
#
#
# # 964
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90556704]
#  [0.86645679]
#  [0.89659099]]
# Loss:
# 9.781380991587854e-05
#
#
# # 965
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90556865]
#  [0.86645564]
#  [0.89659041]]
# Loss:
# 9.779085625421308e-05
#
#
# # 966
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90557027]
#  [0.8664545 ]
#  [0.89658983]]
# Loss:
# 9.77679107117633e-05
#
#
# # 967
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90557188]
#  [0.86645336]
#  [0.89658925]]
# Loss:
# 9.774497328369369e-05
#
#
# # 968
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90557348]
#  [0.86645222]
#  [0.89658867]]
# Loss:
# 9.772204396516892e-05
#
#
# # 969
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90557509]
#  [0.86645108]
#  [0.89658809]]
# Loss:
# 9.769912275136818e-05
#
#
# # 970
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9055767 ]
#  [0.86644994]
#  [0.89658752]]
# Loss:
# 9.767620963746233e-05
#
#
# # 971
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90557831]
#  [0.8664488 ]
#  [0.89658694]]
# Loss:
# 9.765330461863698e-05
#
#
# # 972
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90557992]
#  [0.86644767]
#  [0.89658636]]
# Loss:
# 9.763040769007292e-05
#
#
# # 973
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90558153]
#  [0.86644653]
#  [0.89658578]]
# Loss:
# 9.760751884696077e-05
#
#
# # 974
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90558313]
#  [0.86644539]
#  [0.8965852 ]]
# Loss:
# 9.758463808448993e-05
#
#
# # 975
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90558474]
#  [0.86644425]
#  [0.89658462]]
# Loss:
# 9.756176539786307e-05
#
#
# # 976
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90558635]
#  [0.86644311]
#  [0.89658404]]
# Loss:
# 9.753890078227754e-05
#
#
# # 977
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90558796]
#  [0.86644198]
#  [0.89658347]]
# Loss:
# 9.751604423293336e-05
#
#
# # 978
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90558956]
#  [0.86644084]
#  [0.89658289]]
# Loss:
# 9.749319574504623e-05
#
#
# # 979
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90559117]
#  [0.8664397 ]
#  [0.89658231]]
# Loss:
# 9.747035531382232e-05
#
#
# # 980
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90559277]
#  [0.86643857]
#  [0.89658173]]
# Loss:
# 9.744752293448025e-05
#
#
# # 981
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90559438]
#  [0.86643743]
#  [0.89658115]]
# Loss:
# 9.742469860224102e-05
#
#
# # 982
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90559598]
#  [0.8664363 ]
#  [0.89658057]]
# Loss:
# 9.7401882312327e-05
#
#
# # 983
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90559759]
#  [0.86643516]
#  [0.89658   ]]
# Loss:
# 9.737907405996728e-05
#
#
# # 984
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90559919]
#  [0.86643403]
#  [0.89657942]]
# Loss:
# 9.73562738403911e-05
#
#
# # 985
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90560079]
#  [0.8664329 ]
#  [0.89657884]]
# Loss:
# 9.733348164883496e-05
#
#
# # 986
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9056024 ]
#  [0.86643176]
#  [0.89657826]]
# Loss:
# 9.73106974805423e-05
#
#
# # 987
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.905604  ]
#  [0.86643063]
#  [0.89657769]]
# Loss:
# 9.728792133075013e-05
#
#
# # 988
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9056056 ]
#  [0.8664295 ]
#  [0.89657711]]
# Loss:
# 9.726515319471132e-05
#
#
# # 989
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9056072 ]
#  [0.86642837]
#  [0.89657653]]
# Loss:
# 9.72423930676743e-05
#
#
# # 990
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90560881]
#  [0.86642723]
#  [0.89657595]]
# Loss:
# 9.721964094489493e-05
#
#
# # 991
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90561041]
#  [0.8664261 ]
#  [0.89657538]]
# Loss:
# 9.719689682162983e-05
#
#
# # 992
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90561201]
#  [0.86642497]
#  [0.8965748 ]]
# Loss:
# 9.717416069314488e-05
#
#
# # 993
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90561361]
#  [0.86642384]
#  [0.89657422]]
# Loss:
# 9.715143255470513e-05
#
#
# # 994
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90561521]
#  [0.86642271]
#  [0.89657364]]
# Loss:
# 9.712871240158166e-05
#
#
# # 995
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90561681]
#  [0.86642158]
#  [0.89657307]]
# Loss:
# 9.710600022904873e-05
#
#
# # 996
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90561841]
#  [0.86642045]
#  [0.89657249]]
# Loss:
# 9.708329603238686e-05
#
#
# # 997
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90562001]
#  [0.86641932]
#  [0.89657191]]
# Loss:
# 9.706059980687485e-05
#
#
# # 998
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90562161]
#  [0.86641819]
#  [0.89657133]]
# Loss:
# 9.703791154779922e-05
#
#
# # 999
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90562321]
#  [0.86641706]
#  [0.89657076]]
# Loss:
# 9.701523125044987e-05
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [[1. 1.]]
# Output:
# [[0.92809552]]
